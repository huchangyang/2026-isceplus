# %% [markdown]
# # Dolphin walkthrough for OPERA geocoded CSLCs
#
# This notebook demonstrates the basic usage of the `dolphin` command line tool to execute the stack-based phase linking workflow.
# In this notebook, we will
#
# - Download geocoded, co-registered single-look complex (CSLC) radar images from [ASF](https://search.asf.alaska.edu/)
# - Prepare a configuration file for a stack of coregistered single-look complex (SLC) radar images with `dolphin config`
# - Run this configuration file with `dolphin run`
# - Inspect the resulting output interferograms
# - Show the most common parameters you may want to change or customize

# %% [markdown]
# ## Setup
#
# We first need to install `dolphin` as outlined in the [Getting Started](https://dolphin-insar.readthedocs.io/en/latest/getting-started/) section of the documentation. You can install `dolphin` with either `conda` (recommended) or `pip` (if a `gdal` installation is availble to the environment)

# %% [markdown]
# We can check that we have the command line tool correctly installed by running:

# %%
# %pip install --upgrade "dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott
#   Cloning https://github.com/scottstanie/dolphin.git (to revision develop-scott) to /tmp/pip-install-kos64c0r/dolphin_5e7128824a7c46919ecdd36998b90181
#   Running command git clone --filter=blob:none --quiet https://github.com/scottstanie/dolphin.git /tmp/pip-install-kos64c0r/dolphin_5e7128824a7c46919ecdd36998b90181
#   Running command git checkout -b develop-scott --track origin/develop-scott
#   Switched to a new branch 'develop-scott'
#   branch 'develop-scott' set up to track 'origin/develop-scott'.
#   Resolved https://github.com/scottstanie/dolphin.git to commit c9f6c10ceac11703e655c9628d91aac848387aaa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: h5py>=3.6 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.13.0)
# Requirement already satisfied: jax>=0.4.19 in /home/jovyan/.local/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.10.2)
# Requirement already satisfied: numba>=0.56 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.66.0)
# Requirement already satisfied: numpy>=1.23 in /home/jovyan/.local/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.4.6)
# Requirement already satisfied: opera-utils>=0.25.7 in /home/jovyan/.local/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.25.8.post1.dev28+g8d3bd85a1)
# Requirement already satisfied: pydantic>=2.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.13.4)
# Requirement already satisfied: pyproj>=3.3 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.7.2)
# Requirement already satisfied: rasterio>=1.3 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.4.3)
# Requirement already satisfied: ruamel_yaml>=0.15 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.19.1)
# Requirement already satisfied: scipy>=1.9 in /home/jovyan/.local/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.17.1)
# Requirement already satisfied: snaphu>=0.4.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.4.1)
# Requirement already satisfied: threadpoolctl>=3.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.6.0)
# Requirement already satisfied: tqdm>=4.60 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (4.69.0)
# Requirement already satisfied: tyro>=0.9.20 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.0.15)
# Requirement already satisfied: jaxlib<=0.10.2,>=0.10.1 in /home/jovyan/.local/lib/python3.11/site-packages (from jax>=0.4.19->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.10.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/jovyan/.local/lib/python3.11/site-packages (from jax>=0.4.19->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.5.4)
# Requirement already satisfied: opt_einsum in /home/jovyan/.local/lib/python3.11/site-packages (from jax>=0.4.19->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.4.0)
# Requirement already satisfied: llvmlite<0.49,>=0.48.0dev0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from numba>=0.56->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.48.0)
# Requirement already satisfied: aiohttp in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.14.3)
# Requirement already satisfied: fsspec in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2026.6.0)
# Requirement already satisfied: pooch>=1.7 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.9.0)
# Requirement already satisfied: rich in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (15.0.0)
# Requirement already satisfied: s3fs in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.4.2)
# Requirement already satisfied: shapely>=1.8 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.1.1)
# Requirement already satisfied: typing_extensions>=4 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (4.11.0)
# Requirement already satisfied: packaging>=20.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (26.2)
# Requirement already satisfied: requests>=2.19.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.34.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pydantic>=2.1->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pydantic>=2.1->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pydantic>=2.1->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.4.2)
# Requirement already satisfied: certifi in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from pyproj>=3.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2026.7.22)
# Requirement already satisfied: affine in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.4.0)
# Requirement already satisfied: attrs in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (26.1.0)
# Requirement already satisfied: click>=4.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (8.4.2)
# Requirement already satisfied: cligj>=0.5 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.7.2)
# Requirement already satisfied: click-plugins in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.1.1.2)
# Requirement already satisfied: pyparsing in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rasterio>=1.3->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.7->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.5.0)
# Requirement already satisfied: docstring-parser>=0.16 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from tyro>=0.9.20->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from tyro>=0.9.20->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (4.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from aiohttp->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.24.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rich->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from rich->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (0.1.2)
# Requirement already satisfied: botocore>=1.12.91 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from s3fs->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.43.55)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from botocore>=1.12.91->s3fs->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from botocore>=1.12.91->s3fs->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /tmp/.pixi/envs/default/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.12.91->s3fs->opera-utils>=0.25.7->dolphin @ git+https://github.com/scottstanie/dolphin.git@develop-scott) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import site
import shutil

user_bin = os.path.join(site.USER_BASE, "bin")
os.environ["PATH"] = user_bin + os.pathsep + os.environ.get("PATH", "")

print("Added to PATH:", user_bin)
print("dolphin:", shutil.which("dolphin"))
# Out:
# Added to PATH: /home/jovyan/.local/bin
# dolphin: /home/jovyan/.local/bin/dolphin

# %%
# !dolphin --help
# Out:
# usage: dolphin [-h] {run,config,unwrap,timeseries,filter,geocode}
#
# ╭─ options ────────────────────────────────────────────────────────────────────╮
# │ -h, --help      show this help message and exit                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ subcommands ────────────────────────────────────────────────────────────────╮
# │ (required)                                                                   │
# │   • run         Run the displacement workflow.                               │
# │   • config      Create a configuration file for a displacement workflow.     │
# │   • unwrap      Run snaphu on all interferograms in a directory.             │
# │   • timeseries  Invert the unwrapped interferograms, estimate timeseries and │
# │                 phase velocity.                                              │
# │   • filter      Filter a list of unwrapped interferogram files using a       │
# │                 long-wavelength filter.                                      │
# │   • geocode     Geocode rasters using latitude/longitude geolocation arrays. │
# │                                                                              │
# │                 Transforms rasters from radar/swath geometry to geographic   │
# │                 coordinates using per-pixel lat/lon arrays (e.g., from       │
# │                 ISCE2/ISCE3 topo).                                           │
# │                                                                              │
# │                 Provide either ``-i`` for specific files or ``-d`` to        │
# │                 bulk-geocode all outputs in a dolphin work directory.        │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# or by importing dolphin in python

# %%
import dolphin

dolphin.show_versions()
# Out:
# dolphin version: 0.26.0.post1.dev369+gc9f6c10ce
#
# Python deps:
#         h5py: 3.13.0
#          jax: 0.10.2
#        numba: 0.66.0
#        numpy: 2.4.6
#  opera-utils: 0.25.8.post1.dev28+g8d3bd85a1
#     pydantic: 2.13.4
#       pyproj: 3.7.2
#     rasterio: 1.4.3
#  ruamel_yaml: None
#        scipy: 1.17.1
#       snaphu: 0.4.1
# threadpoolctl: 3.6.0
#         tqdm: 4.69.0
#         tyro: 1.0.15
#   osgeo.gdal: 3.10.3
#
# System:
#       python: 3.11.15 | packaged by conda-forge | (main, Jun 11 2026, 03:34:02) [GCC 14.3.0]
#   executable: /tmp/.pixi/envs/default/bin/python
#      machine: Linux-6.12.94-123.190.amzn2023.x86_64-x86_64-with-glibc2.39
# Unwrapping packages:
# snaphu : 0.4.1
# spurt : None
# isce3 : 0.24.4
# tophu : None
# whirlwind : 0.9.0
#       snaphu: 0.4.1
#        spurt: None
#        isce3: 0.24.4
#        tophu: None
#    whirlwind: 0.9.0
# optional GPU info:
#          jax: 0.10.2
# gpu_is_available: False

# %% [markdown]
# If you have a GPU available to you, you can follow the [extra installation set up](https://dolphin-insar.readthedocs.io/en/latest/gpu-setup/) so that the GPU verion of the workflow run.
# This can be 5-20x faster than the CPU version for the phase linking portion, depending on the size of your workstation.
# Here we will be processing a relatively small area, so the CPU will suffice.

# %% [markdown]
# ## Input dataset
#
# To find input data, you can use the [ASF search UI](https://search.asf.alaska.edu/) to explore and get a list of URLs to download; for our purposes, we will use the [OPERA Co-regisred Single-look Complex product](https://www.jpl.nasa.gov/go/opera/products/cslc-product-suite), which `dolphin` can directly process.
#
# The helper functions in the [`opera-utils`](https://github.com/opera-adt/opera-utils) library provide wrappers over the [ASF library](https://github.com/asfadmin/Discovery-asf_search) to make it easy to download OPERA CSLCs over a certain region.
# Additionally, `opera-utils` has the ability to filter queries with "missing bursts" (due to irregular Sentinel-1 acquisitions over North America) to ensure that all dates present have the same spatial coverage.
#
# We will search for a stack of Sentinel-1 SLCs over New Orleans (ascending track 165).

# %% [markdown]
# Since ASF requires a login to download data, you must authenticate with your Earthdata credentials.
# We will assume that a `~/.netrc` file is set up with the correct permissions.

# %%
from pathlib import Path

import shapely
import opera_utils.download

aoi = "POLYGON((-90.3038 29.8923,-90.0278 29.8992,-90.0262 30.0538,-90.3205 30.06,-90.3038 29.8923))"
start = "2022-01-01"
end = "2023-01-01"
burst_ids = ["T165-352434-IW2", "T165-352435-IW2"]
bounds = shapely.from_wkt(aoi).bounds


results, options = opera_utils.download.search_cslcs(
    burst_ids=burst_ids,
    start=start,
    end=end,
    # We want to have the same set of dates for each Burst ID (spatial footprint)
    check_missing_data=True,
    # We have already picked out the Burst Ids that we will use.
    # An alternative is to use a WKT polygon, with or without a track number specified
    # aoi_polygon=aoi,
)
best_option = options[0]
print(f"Found {len(best_option.inputs)} CSLCs to download between {start} and {end}")
# Out:
# Found 44 CSLCs to download between 2022-01-01 and 2023-01-01

# %%
import os

import asf_search as asf

work_dir = Path("new-orleans")
work_dir.mkdir(parents=True, exist_ok=True)
os.chdir(work_dir)

slc_dir = Path("input_slcs")
slc_dir.mkdir(parents=True, exist_ok=True)
asf.download_urls(best_option.inputs, path=slc_dir)

# %% [markdown]
# In the `input_slcs` directory, we have stored the NetCDF-format SLCs:

# %%
# !ls input_slcs | head -3
# !ls input_slcs | wc
# Out:
# OPERA_L2_CSLC-S1_T165-352434-IW2_20220108T000229Z_20240731T082832Z_S1A_VV_v1.1.h5
# OPERA_L2_CSLC-S1_T165-352434-IW2_20220120T000228Z_20240731T110350Z_S1A_VV_v1.1.h5
# OPERA_L2_CSLC-S1_T165-352434-IW2_20220201T000228Z_20240731T144900Z_S1A_VV_v1.1.h5
#      44      44    3608

# %% [markdown]
# See the [OPERA CSLC documentation](https://d2pn8kiwq2w21t.cloudfront.net/documents/OPERA_CSLC-S1_ProductSpec_v1.0.0_D-108278_Initial_2023-09-11_URS321269.pdf) for the full filename convention, but the main points are
#
# - `T165` is Sentinel-1 track (relative orbit) 165
# - 352434 the Burst IDs from [ESA's Burst database](https://sar-mpc.eu/test-data-sets/)
# - `IW2` indicates these are from the first subswath (since the "Burst ID" is repeated for subswaths IW1,2,3.)
# - `20220108T000229Z` is the acquisition datetime (in UTC)
#
# Note that we specified the data we want is in `/data/VV`. This is not necessary for other SLC formats (e.g. binary files from ISCE2) which have only one raster layer.
#
# You can process one single stack, or multiple geocoded stacks. If you have different spatial regions, as is the case with OPERA CSLCs, `dolphin` will form burst-wise interferograms and stitch them before unwrapping.

# %% [markdown]
# Let's make a configuration file for all of the bursts:

# %%
# !dolphin config --slc-files input_slcs/*.h5 --subdataset "/data/VV"
# Out:
# Saving configuration to dolphin_config.yaml

# %% [markdown]
# You can inspect the YAML file to see all configuration options.

# %% [markdown]
# ### Common configuration
#
# #### Strides
# You can create a downsampled version of the output using `--output-options.strides.x` (or `--sx` for short) and `--sy`.
# This will save time/space by creation an output with coarser pixel spacing than your SLCs.
# For COMPASS outputs, adding `--sx 6 --sy 3` will convert the inputs at (5m, 10m) in `(x, y)` (aka `(easting, northing)`) to a (30 meter, 30 meter) output.
#
#
# #### Specify the working directory
#
# Use `--work-directory` to save all rasters to a different directory other than the one you call `dolphin run` from.
#
# #### Specify how many bursts, or patches, to process in parallel
#
# By adding the `--n-parallel-bursts`, you can process separate geocoded bursts at the same time (assuming sufficient resources are available). On a large single stack (like the flat binary files from isce2, or NISAR swaths), this option controls the number of parallel blocks to process during phase linking.
#
# Additionally, use `--threads-per-worker` to limit the number of CPUs you would like the workflow to use, especially on large workstations.
#
# #### Mini-stack size for phase linking
#
# When processing many (dozens to hundreds) of SLCs, `dolphin` will use the strategy of batching SLCs into "mini-stacks", rather than processing the entire stack at once. The default is to use batch of 15 dates at a time, but this can be changed with `--phase-linking.ministack-size` or `--ms`. For example, you may want to try processing all dates at once (likely a slower processing time), or you may want to adjust the number slightly (if, e.g., you have 46 dates and would rather not leave the last batch with one remaining).
#
# #### Phase unwrapping
#
# `dolphin` supports multiple options for phase unwrapping. Here, we will use the [Python wrapper for SNAPHU](https://github.com/isce-framework/snaphu-py), one of the most widely used phase unwrapping algorithms.
#
# #### Bounds subsetting
#
# If you are interested in a smaller subset of the area, you can specify the `--output-bounds` to force the raster boundaries.

# %%
# !wget https://gist.githubusercontent.com/scottstanie/7f339a391e58947bee8e52a490448443/raw/b78830f1e5abcfd542a6b922ab2986aec7a2ed93/create_water_mask.py
# Out:
# --2026-08-07 02:37:07--  https://gist.githubusercontent.com/scottstanie/7f339a391e58947bee8e52a490448443/raw/b78830f1e5abcfd542a6b922ab2986aec7a2ed93/create_water_mask.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11101 (11K) [text/plain]
# Saving to: ‘create_water_mask.py’
#
# create_water_mask.p 100%[===================>]  10.84K  --.-KB/s    in 0s
#
# 2026-08-07 02:37:07 (31.7 MB/s) - ‘create_water_mask.py’ saved [11101/11101]

# %%
# !python create_water_mask.py \
    --bounds -90.5 29.85 -89.8  30.2 \
    --output water_mask.tif 
 # make water pixels = 0, land = 1
# Out:
# INFO: Using 4 tile(s): ['n30w095.tif', 'n25w095.tif', 'n30w090.tif', 'n25w090.tif']
# INFO: Created water mask: water_mask.tif

# %%
from dolphin.io import load_gdal
plt.figure()
plt.imshow(load_gdal("water_mask.tif"))
plt.colorbar()

# %%
# !aws s3 cp s3://earthscope-insar2025/dolphin-opera-cslcs/water_mask.tif ./

# %%
# %%bash
# dolphin config \
#     --slc-files input_slcs/*.h5 \
#     --subdataset "/data/VV" \
#     --mask-file water_mask.tif \
#     --sx 6 --sy 3 \
#     --interferogram-network.max-bandwidth 3 \
#     --n-parallel-bursts 2 \
#     --ms 16 \
#     --unwrap-options.n-parallel-jobs 3 \
#     --unwrap-options.unwrap-method WHIRLWIND \
#     --output-options.bounds -90.3205 29.8923 -90.0262 30.06 \
#     --work-directory dolphin
# Out:
# Saving configuration to dolphin_config.yaml

# %% [markdown]
# ## Running the workflow
#
# Now that we have created the `dolphin_config.yaml` file, we can run it using `dolphin run`

# %%
# %%capture outputs
# To see all the output logging, remove the line above

import os

# TQDM doesn't play nicely with notebook outputs, not like terminal
os.environ["TQDM_DISABLE"] = "1"

# Running from the command line
# !dolphin run dolphin_config.yaml

# Running within python:
from dolphin.workflows import displacement, DisplacementWorkflow
cfg = DisplacementWorkflow.from_yaml("dolphin_config.yaml")
displacement.run(cfg)
# Out:
# [INFO|wrapped_phase|L117] 2026-08-07T13:42:00+0000: Running wrapped phase estimation in /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2
# [INFO|wrapped_phase|L117] 2026-08-07T13:42:00+0000: Running wrapped phase estimation in /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2
# [INFO|masking|L317] 2026-08-07T13:42:02+0000: Creating mask for bounds POLYGON ((-90.0262 29.8923, -90.0262 30.06, -90.3205 30.06, -90.3205 29.8923, -90.0262 29.8923))
# [INFO|masking|L317] 2026-08-07T13:42:02+0000: Creating mask for bounds POLYGON ((-90.0262 29.8923, -90.0262 30.06, -90.3205 30.06, -90.3205 29.8923, -90.0262 29.8923))
# [INFO|masking|L341] 2026-08-07T13:42:02+0000: Created /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/bounds_mask.tif
# [INFO|masking|L341] 2026-08-07T13:42:02+0000: Created /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/bounds_mask.tif
# [INFO|wrapped_phase|L164] 2026-08-07T13:42:03+0000: Creating persistent scatterer file /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/PS/ps_pixels.tif
# [INFO|wrapped_phase|L164] 2026-08-07T13:42:03+0000: Creating persistent scatterer file /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/PS/ps_pixels.tif
# [INFO|_readers|L1169] 2026-08-07T13:42:04+0000: Processing (512, 512) sized blocks...
# [INFO|_readers|L1169] 2026-08-07T13:42:04+0000: Processing (512, 512) sized blocks...
# [INFO|_amp_dispersion|L202] 2026-08-07T13:42:28+0000: Waiting to write 0 blocks of data.
# [INFO|_amp_dispersion|L205] 2026-08-07T13:42:28+0000: Repacking PS rasters for better compression
# [INFO|_amp_dispersion|L209] 2026-08-07T13:42:34+0000: Finished writing out PS files
# [INFO|_amp_dispersion|L382] 2026-08-07T13:42:34+0000: Saving a looked PS mask to /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/PS/ps_pixels_looked.tif
# [INFO|_amp_dispersion|L202] 2026-08-07T13:42:37+0000: Waiting to write 0 blocks of data.
# [INFO|wrapped_phase|L238] 2026-08-07T13:42:37+0000: Running sequential EMI step in /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase
# [INFO|sequential|L101] 2026-08-07T13:42:37+0000: File range start: OPERA_L2_CSLC-S1_T165-352434-IW2_20220108T000229Z_20240731T082832Z_S1A_VV_v1.1.h5
# [INFO|sequential|L102] 2026-08-07T13:42:37+0000: File range end: OPERA_L2_CSLC-S1_T165-352434-IW2_20221222T000235Z_20240802T041250Z_S1A_VV_v1.1.h5
# [INFO|sequential|L103] 2026-08-07T13:42:37+0000: Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase
# [INFO|sequential|L104] 2026-08-07T13:42:37+0000: Number of ministacks of size 16: 2
# [INFO|sequential|L132] 2026-08-07T13:42:37+0000: Processing 16 SLCs. Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/20220108_20221011
# [INFO|_amp_dispersion|L205] 2026-08-07T13:42:37+0000: Repacking PS rasters for better compression
# [INFO|single|L90] 2026-08-07T13:42:37+0000: VRTStack(16 bands, outfile=/home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/20220108_20221011.vrt): from [datetime.datetime(2022, 1, 8, 0, 0)] to [datetime.datetime(2022, 10, 11, 0, 0)]
# [INFO|single|L109] 2026-08-07T13:42:37+0000: Processing 16 SLCs + 0 compressed SLCs.
# [INFO|single|L114] 2026-08-07T13:42:37+0000: Total stack size (in pixels): (16, 4494, 20598)
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# [INFO|_amp_dispersion|L209] 2026-08-07T13:42:43+0000: Finished writing out PS files
# [INFO|_amp_dispersion|L382] 2026-08-07T13:42:43+0000: Saving a looked PS mask to /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/PS/ps_pixels_looked.tif
# [INFO|wrapped_phase|L238] 2026-08-07T13:42:46+0000: Running sequential EMI step in /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase
# [INFO|sequential|L101] 2026-08-07T13:42:46+0000: File range start: OPERA_L2_CSLC-S1_T165-352435-IW2_20220108T000232Z_20240731T082832Z_S1A_VV_v1.1.h5
# [INFO|sequential|L102] 2026-08-07T13:42:46+0000: File range end: OPERA_L2_CSLC-S1_T165-352435-IW2_20221222T000238Z_20240802T041250Z_S1A_VV_v1.1.h5
# [INFO|sequential|L103] 2026-08-07T13:42:46+0000: Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase
# [INFO|sequential|L104] 2026-08-07T13:42:46+0000: Number of ministacks of size 16: 2
# [INFO|sequential|L132] 2026-08-07T13:42:46+0000: Processing 16 SLCs. Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/20220108_20221011
# [INFO|single|L90] 2026-08-07T13:42:47+0000: VRTStack(16 bands, outfile=/home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/20220108_20221011.vrt): from [datetime.datetime(2022, 1, 8, 0, 0)] to [datetime.datetime(2022, 10, 11, 0, 0)]
# [INFO|single|L109] 2026-08-07T13:42:47+0000: Processing 16 SLCs + 0 compressed SLCs.
# [INFO|single|L114] 2026-08-07T13:42:47+0000: Total stack size (in pixels): (16, 4488, 20604)
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# [INFO|single|L429] 2026-08-07T13:45:07+0000: Waiting to write 38 blocks of data.
# [INFO|single|L431] 2026-08-07T13:45:08+0000: Finished ministack of size (16, 4494, 20598).
# [INFO|single|L434] 2026-08-07T13:45:08+0000: Repacking phase linking outputs for more compression
# [INFO|single|L437] 2026-08-07T13:45:13+0000: Creating similarity raster on outputs
# [INFO|single|L448] 2026-08-07T13:45:25+0000: Repacking CRLB files for more compression
# [INFO|sequential|L132] 2026-08-07T13:45:30+0000: Processing 7 SLCs. Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/20221023_20221222
# [INFO|single|L90] 2026-08-07T13:45:30+0000: VRTStack(7 bands, outfile=/home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/20221023_20221222.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 10, 11, 0, 0)) to [datetime.datetime(2022, 12, 22, 0, 0)]
# [INFO|single|L109] 2026-08-07T13:45:30+0000: Processing 6 SLCs + 1 compressed SLCs.
# [INFO|single|L114] 2026-08-07T13:45:30+0000: Total stack size (in pixels): (7, 4494, 20598)
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# [INFO|single|L429] 2026-08-07T13:45:57+0000: Waiting to write 0 blocks of data.
# [INFO|single|L431] 2026-08-07T13:45:57+0000: Finished ministack of size (16, 4488, 20604).
# [INFO|single|L434] 2026-08-07T13:45:57+0000: Repacking phase linking outputs for more compression
# [INFO|single|L437] 2026-08-07T13:46:03+0000: Creating similarity raster on outputs
# [INFO|single|L448] 2026-08-07T13:46:23+0000: Repacking CRLB files for more compression
# [INFO|sequential|L132] 2026-08-07T13:46:27+0000: Processing 7 SLCs. Output folder: /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/20221023_20221222
# [INFO|single|L90] 2026-08-07T13:46:28+0000: VRTStack(7 bands, outfile=/home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/20221023_20221222.vrt): from (datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 10, 11, 0, 0)) to [datetime.datetime(2022, 12, 22, 0, 0)]
# [INFO|single|L109] 2026-08-07T13:46:28+0000: Processing 6 SLCs + 1 compressed SLCs.
# [INFO|single|L114] 2026-08-07T13:46:28+0000: Total stack size (in pixels): (7, 4488, 20604)
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# [INFO|single|L429] 2026-08-07T13:47:05+0000: Waiting to write 18 blocks of data.
# [INFO|single|L431] 2026-08-07T13:47:05+0000: Finished ministack of size (7, 4494, 20598).
# [INFO|single|L434] 2026-08-07T13:47:05+0000: Repacking phase linking outputs for more compression
# [INFO|single|L437] 2026-08-07T13:47:10+0000: Creating similarity raster on outputs
# [INFO|single|L448] 2026-08-07T13:47:16+0000: Repacking CRLB files for more compression
# [INFO|sequential|L300] 2026-08-07T13:47:21+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/temporal_coherence_average_20220108_20221222.tif
# [INFO|sequential|L300] 2026-08-07T13:47:21+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/closure_phase_coh_average_20220108_20221222.tif
# [INFO|sequential|L300] 2026-08-07T13:47:21+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352434_iw2/linked_phase/shp_counts_average_20220108_20221222.tif
# [INFO|wrapped_phase|L294] 2026-08-07T13:47:27+0000: wrapped_phase complete
# [INFO|wrapped_phase|L324] 2026-08-07T13:47:27+0000: Creating virtual interferograms from 22 files
# [INFO|_log|L102] 2026-08-07T13:47:27+0000: Total elapsed time for dolphin.workflows.wrapped_phase.run : 5.45 minutes (326.98 seconds)
# /home/jovyan/.local/lib/python3.11/site-packages/jax/_src/scipy/linalg.py:170: FutureWarning: jax.scipy.linalg.cho_solve: batched 1D solves with b.ndim > 1 are deprecated, and in the future will be treated as a batched 2D solve. Use cho_solve(c_and_lower, b[..., None]).squeeze(-1) to avoid this warning.
#   warnings.warn(
# [INFO|single|L429] 2026-08-07T13:48:21+0000: Waiting to write 0 blocks of data.
# [INFO|single|L431] 2026-08-07T13:48:22+0000: Finished ministack of size (7, 4488, 20604).
# [INFO|single|L434] 2026-08-07T13:48:22+0000: Repacking phase linking outputs for more compression
# [INFO|single|L437] 2026-08-07T13:48:26+0000: Creating similarity raster on outputs
# [INFO|single|L448] 2026-08-07T13:48:37+0000: Repacking CRLB files for more compression
# [INFO|sequential|L300] 2026-08-07T13:48:40+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/temporal_coherence_average_20220108_20221222.tif
# [INFO|sequential|L300] 2026-08-07T13:48:40+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/closure_phase_coh_average_20220108_20221222.tif
# [INFO|sequential|L300] 2026-08-07T13:48:41+0000: Averaging 2 files into /home/jovyan/2026-isceplus/5.3_Intro_to_Dolphin/dolphin-opera-cslcs/new-orleans/dolphin/t165_352435_iw2/linked_phase/shp_counts_average_20220108_20221222.tif
# [INFO|wrapped_phase|L294] 2026-08-07T13:48:49+0000: wrapped_phase complete
# [INFO|wrapped_phase|L324] 2026-08-07T13:48:49+0000: Creating virtual interferograms from 22 files
# [INFO|_log|L102] 2026-08-07T13:48:49+0000: Total elapsed time for dolphin.workflows.wrapped_phase.run : 6.82 minutes (409.16 seconds)

# %% [markdown]
# ## Visualizing the displacement
#
# The outputs can be plotted using any tool capable of reading GDAL-compatible rasters. You can also use the `dolphin.io.load_gdal` function for convenience.

# %%
file_list = sorted(Path("dolphin/timeseries/").glob("2*.tif"))
print(f"Found {len(file_list)} timeseries files")
# Out:
# Found 21 timeseries files

# %%
import matplotlib.pyplot as plt
import numpy as np
from opera_utils import get_dates

from dolphin.io import load_gdal

# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(6, 5))

last_displacement = load_gdal(file_list[-1], masked=True)

axim = ax.imshow(
    last_displacement - np.ma.median(last_displacement),
    cmap="RdBu_r",
    vmax=0.15,
    vmin=-0.15,
)
fig.colorbar(axim, label="LOS [meters]")

fig.tight_layout()

# %% [markdown]
# ### Apppendix: More on the output folders
#
# For each stack of SLCs (which may be > 1 when processing OPERA geocoded burst SLCs), the workflow creates a folder for
# 1. persistent scatter outputs (`PS`)
# 2. linked phase optimized SLCs (`linked_phase`)
# 3. (virtual) interferograms formed using the optimized SLCs (`interferograms`)
#
# Here we have two of these subdirectories named `t042_088905_iw1` and `t042_088906_iw1`.
# At the top level, we have
# - The `slc_stack.vrt` is a VRT file pointing to the input SLCs for that burst stack.
# - The `nodata_mask.tif` has been created from the OPERA CSLC metadata to skip over the nan regions
# - The `bounds_mask.tif` was created to more quickly process a subset of the CSLCS.
#
# Last, there are a top-level directorie for `interferograms` that have been stitched together, `unwrapped` folder for the outputs of phase unwrapping, and `timeseries` for the result of inverting in unwrapped interferograms (if a network of redundant interferograms were created).
#
# ```
# $ tree -L 1 work-walkthrough/
# work-walkthrough/
# ├── dolphin.log
# ├── interferograms
# ├── t078_165573_iw2
# ├── t078_165574_iw2
# ├── timeseries
# └── unwrapped
#
# $ tree -L 1 work-walkthrough/t078_165574_iw2/
# work-walkthrough/t078_165574_iw2/
# ├── PS
# ├── bounds_mask.tif
# ├── combined_mask.tif
# ├── interferograms
# ├── linked_phase
# ├── nodata_mask.tif
# ├── slc_stack.vrt
# ├── timeseries
# └── unwrapped
#
# ```
